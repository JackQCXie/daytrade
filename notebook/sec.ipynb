# %%
import requests
from lxml import html
import json

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
    # 'cookie' : 'bm_mi=AFA1335B5C55B519644647415A9FAE07~~1; ak_bmsc=A9CDF8AFCF975D8086741010F04E3782~000000000000000000000000000000~...; bm_sv=FC9D2D969907E0D20D3F32B743DA3415~YAAQnvTVF4MjdAaZAQAAtDy4HR1GOEoDm2Fk1N+c+f5TvryMWE8WE2ZA2Kcttfv6018lbZzxJX5ACQFc00pgJB8+0eW6hhJGyL+Xdsq86dnR9tWEZE+xgI/dv0R33+EbDueVxRtlsZ6rfzw7t7EiTy45XN+jFCINSiRPNRKEyZhrA7Jdb/tY/jcM5xU+Iq24Exz6MjXOG2GC/JX3wl1ulsgNFffM3Eu+H11Qxjh7vR5aB1DqvkywSJho0eVnQw==~1',
    'accept': 'application/json',
    }

resp = requests.get(url, headers=headers)
print(resp)
print(resp.text)
